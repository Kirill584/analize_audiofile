# %%
# !py Data.py -h
# Out:
# Подключение к БД прошло успешно.
# usage: Программа для вывода информации об аудиофайле [-h] [-f FILE]
#                                                      [-fl FOLDER] [-d DATE]
#                                                      [-a ARTIST] [-s SORT]
#                                                      [-g GENRE]
#
# Если на вход программы подаётся путь к файлу - выдается информация об этом
# файле и данные записываются в БД. Если на вход программы подаётся путь к папке
# - выдается информация о каждом файле в этой папке и данные о каждом файле
# записываются в БД. Так же с помощью некоторых параметров можно получить
# выборку песен из БД. Для работы программы нужны определенные папки: covers - в
# эту папку будут сохраняться обложки песен, musics - папка, в которой будут
# храниться песни для анализа, spect - в эту папку будут сохраняться
# спектограммы песен.
#
# options:
#   -h, --help            Показать справку и выйти
#   -f FILE, --file FILE  Путь к файлу
# ...

# %%
# !py Data.py -f musics/music2.mp3
# Out:
# Подключение к БД прошло успешно.
# Namespace(file='musics/MACAN-ASPHALT8.mp3', folder=None, date=None, artist='', sort=None, genre=None)
#
# Получение информации...
# c:\Мос Политех\2 курс\4 семестр\ООП\oop_4semestr_python\course_project\Data.py:57: UserWarning: PySoundFile failed. Trying audioread instead.
#   y, sr = librosa.load(file)
# C:\Users\Кирилл\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\audio.py:184: FutureWarning: librosa.core.audio.__audioread_load
# 	Deprecated as of librosa version 0.10.0.
# 	It will be removed in librosa version 1.0.
#   y, sr_native = __audioread_load(path, offset, duration, dtype)
# Traceback (most recent call last):
#   File "C:\Users\Кирилл\AppData\Local\Programs\Python\Python311\Lib\site-packages\librosa\core\audio.py", line 176, in load
#     y, sr_native = __soundfile_load(path, offset, duration, dtype)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %%
# !py Data.py -fl musics

# %%
# !py Data.py -s musics/music8.mp3
# Out:
# Подключение к БД прошло успешно.
# Namespace(file=None, folder=None, spect='musics/music8.mp3', cover=None)
#
# Figure(1400x500)

# %%
from Data import Data as d
d.get_spect("musics/music8.mp3")

# %%
# !py Data.py -c musics/music8.mp3
# Out:
# Подключение к БД прошло успешно.
# Namespace(file=None, folder=None, spect=None, cover='musics/music8.mp3')
# ...

# %%
from Data import Data as d
d.get_cover("musics/music8.mp3")
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=289x162>

# %%
# !py Data.py -d 2021
# Out:
# Подключение к БД прошло успешно.
# Namespace(file=None, folder=None, date='2021', artist=None, sort=None, genre=None)
# Песни, выпущенные после 2021 года:
# +---------------------+----------------+------------+
# |        title        |     artist     |    date    |
# +---------------------+----------------+------------+
# |      ASPHALT 8      |     MACAN      |    2023    |
# |         Дом         |    NABOKOVA    | 2023-01-30 |
# |        Когда        |    NABOKOVA    | 2023-01-30 |
# | Warm Tropical Chill |   NEONMusic    |    2023    |
# |  Наверно Разные Мы  |     Serpo      |    2022    |
# | Не Виноваты Планеты | Три Дня Дождя  |    2022    |
# |   Не Забывай Меня   |     Mujeva     |    2022    |
# |    Моя хулиганка    |   XOLIDAYBOY   |    2022    |
# |       Отпускай      | Три дня дождя  |    2022    |
# +---------------------+----------------+------------+

# %%
# !py Data.py -a "Death Grips"
# Out:
# Подключение к БД прошло успешно.
# Namespace(file=None, folder=None, date=None, artist='Death Grips', sort=None, genre=None)
# Песни автора Death Grips
# +--------------------+-------------+------------------+-------+
# |       title        |    artist   |      album       | genre |
# +--------------------+-------------+------------------+-------+
# |      Get Got       | Death Grips | The Money Store  |  Нет  |
# | Come Up and Get Me | Death Grips | No Love Deep Web |  Нет  |
# +--------------------+-------------+------------------+-------+

# %%
# !py Data.py -s size
# Out:
# Подключение к БД прошло успешно.
# Namespace(file=None, folder=None, date=None, artist='', sort='size', genre=None)
# Сортировка песен по size
# +------------------------------------------------------------------------------------------------------------------------------+-------------------------------------------------+-----------------------------------------------------------------+------------------------------------------+--------+----------+--------------------------------------+------------+----------------------------+---------------------------------------------------------------------------------+------------+--------------------+-----------+------+-----------------------------------------------+----------+----------+----------+-----------+------+----------+--------+---------+---------+
# ...

# %%
# !py Data.py -g pop
# Out:
# Подключение к БД прошло успешно.
# Namespace(file=None, folder=None, date=None, artist='', sort=None, genre='pop')
# Песни жанра pop
# +---------------+-----------------------------+--------------------------------------+
# |     title     |            artist           |                genre                 |
# +---------------+-----------------------------+--------------------------------------+
# |      Дом      |           NABOKOVA          | Alternative, Indie Pop, Indie Rock,  |
# |     Когда     |           NABOKOVA          | Alternative, Indie Pop, Indie Rock,  |
# |   In My Mind  | Dynoro feat. Gigi DAgostino |              Pop, Dance              |
# | Моя хулиганка |          XOLIDAYBOY         |                ruspop                |
# +---------------+-----------------------------+--------------------------------------+
